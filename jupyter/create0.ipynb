# %% [markdown]
# # search with ami

# %% [markdown]
# ### define the parameters of the search

# %%
import os
from os.path import expanduser
import shutil

# %%
# specific problem
VARS = {}
VARS["PROJECT"] = "funders"
VARS["E_QUERY"] = "viral epidemics"
VARS["G_HITS"] = 100
VARS["AMI_V"] = " -vv "
HOME = expanduser("~")
VARS["WORK"] = HOME + "workspace/work/search/"
VARS["AMI3"] = HOME + "workspace/cmdev/ami3/"
VARS["OPEN_VIRUS"] = HOME + "projects/openVirus/"
VARS["DICT_DIR"] = VARS["OPEN_VIRUS"] + "cambiohack2020/dictionaries/" 

# destination = shutil.copytree($IPYNB, $WORK)
# shutil.rmtree(path)

# %% [markdown]
# ## create dictionaries with `amidict`

# %%
# !amidict -vv create --help
# Out:
# Version: amidict 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.6 x86_64
#
# Usage: amidict create [-hV] [--query[=query]] [-D=<directory>] [-i=FILE]
#                       [--informat=input format] [--linkcol=<linkCol>]
#                       [--sparqlquery=<sparqlQueryFile>] [--termcol=<termCol>]
#                       [--termfile=<termfile>] [--testString=<testString>]
#                       [--wptype=<wptype>] [--sparqlmap=<String=String>[,
#                       <String=String>...]]... [--synonyms=<synonymList>]...
#                       [--transformName=<String=String>[@<String=String>...]]...
#                       [--wikilinks[=<wikiLinks>[,<wikiLinks>...]...]]...
#                       [--namecol=<nameCol>...] [-d=<dictionaryNameList>[,
# ...

# %%
# !amidict -vv create --directory="/Users/pm286/workspace/dictionaries/" --dictionary=chemokine --input="https://en.wikipedia.org/wiki/Chemokine" --namecol="name" --maxcount=10
# Out:
# Version: amidict 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.6 x86_64
#
#
# Generic values (DictionaryCreationTool)
# ...
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@68b6f0d6
# --datacols          : d      null
# --hrefcols          : d      null
# --informat          : d      list
# --linkcol           : d      null
# --maxcount          : m        10
# --namecol           : m      name
# --outformats        : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$DictionaryFileFormat;@13ad5cd3
# --query             : d      null
# --sparqlmap         : d        {}
# --sparqlquery       : d      null
# --synonyms          : d      null
# --template          : d      null
# --termcol           : d      null
# ...

# %%
# !amidict -vv create --directory=directory --dictionary dictionary --outformats xml --terms \
Abamectin Actinomycin Alexidine Amikacin Amphotericin B Ampicillin \
 Verapamil Vinclozolin Virginiamycin Voriconazole
# Out:
# Version: amidict 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.6 x86_64
#
#
# Generic values (DictionaryCreationTool)
# ...
# --testString        : d      null
# --wikilinks         : d [Lorg.contentmine.ami.tools.AbstractAMIDictTool$WikiLink;@68b6f0d6
# --datacols          : d      null
# --hrefcols          : d      null
# --informat          : d      list
# --linkcol           : d      null
# --maxcount          : d 2147483647
# --namecol           : d      null
# --outformats        : m [Lorg.contentmine.ami.tools.AbstractAMIDictTool$DictionaryFileFormat;@4044fb95
# --query             : d      null
# --sparqlmap         : d        {}
# --sparqlquery       : d      null
# --synonyms          : d      null
# --template          : d      null
# --termcol           : d      null
# ...
