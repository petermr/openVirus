# %%
import xml.etree.ElementTree as ET
import string
import os  
import re
import pandas as pd

# %%
train_data_1 = pd.read_csv("merged_final_1.csv")
train_data = train_data_1.iloc[1:] #remove the first row because it appears as data but is acually the title only 
train_data = train_data.sample(frac=1).reset_index(drop=True) #shufffle the dataset
train_data.drop(['Unnamed: 0'], axis=1) 

#train_data_1 = train_data_1.iloc[1:] #remove the first row because it appears as data but is acually the title only 
#train_data = train_data_1.sample(frac=1).reset_index(drop=True)  #shufffle the dataset
# Out:
#                  ArticleId                                               Text  \
# 0    ML_other_1\PMC7220979  alcohol misuse has been associated with negati...
# 1    ML_other_1\PMC7137310  significant advances in the treatment of hiv i...
# 2    ML_other_1\PMC7376523  people living with hiv  plwh  and substance us...
# 3    ML_covid_1\PMC7360122  epidemiological data report that several count...
# 4    ML_other_1\PMC7360605  zhuang et al  investigate how low oxygen level...
# 5    ML_covid_1\PMC7269089  the coronavirus pandemic has impacted medical ...
# 6    ML_covid_1\PMC7451002  coronaviruses are a large family of viruses th...
# 7    ML_covid_1\PMC7451195  in this review  we survey papers addressing is...
# 8    ML_covid_1\PMC7322477  we are beginning to understand how the virus k...
# 9    ML_covid_1\PMC7437681  this case describes the successful pulmonary r...
# 10   ML_other_1\PMC7354487  hiv drug resistance is a major global challeng...
# 11   ML_other_1\PMC7291340  extracellular vesicles  evs  are lipid bilayer...
# 12   ML_covid_1\PMC7434393  the global pandemic has an inherently urban ch...
# 13   ML_other_1\PMC7300204  toll like receptors  tlrs  are a family of pat...
# 14   ML_other_1\PMC7021280  nathan ford and co authors discuss global prio...
# 15   ML_covid_1\PMC7431328  i examine the spillover effects across the thr...
# 16   ML_covid_1\PMC7276874  evans syndrome  es  is a rare condition charac...
# 17   ML_other_1\PMC7052126  hiv tat protein is a critical protein that pla...
# 18   ML_other_1\PMC7364630  in human immunodeficiency virus 1  hiv 1   rev...
# 19   ML_other_1\PMC7272494  genome wide association studies  gwas  have be...
# 20   ML_other_1\PMC7363067  the epidemic of hepatitis c virus  hcv  infect...
# 21   ML_other_1\PMC7361504  human immunodeficiency virus  hiv  infection i...
# 22   ML_covid_1\PMC7445817  public health and pandemic ethics frequently c...
# 23   ML_covid_1\PMC7272892  coronavirus disease 2019  covid 19  is associa...
# 24   ML_other_1\PMC7246454  the hiv infected population is at a dramatical...
# 25   ML_other_1\PMC6927600  antibodies that recognize commensal microbial ...
# 26   ML_other_1\PMC7269431  retroviral replication proceeds through obliga...
# 27   ML_covid_1\PMC7398761  the coronavirus disease 2019  covid 19  pandem...
# 28   ML_covid_1\PMC7361516  infidelity occurs in approximately 25  of marr...
# 29   ML_other_1\PMC7290679  even with an efficient combination of antiretr...
# ..                     ...                                                ...
# 510  ML_other_1\PMC7188407  prep is an effective hiv prevention tool for p...
# 511  ML_other_1\PMC7289344  hiv latency and residual low level hiv replica...
# 512  ML_other_1\PMC7250498  general practitioners  gps  play a key role in...
# 513  ML_covid_1\PMC7331647  our interest derives from a simple fact  the d...
# 514  ML_other_1\PMC7182188  hiv related stigma has been identified as a si...
# 515  ML_other_1\PMC7077288  combination antiretroviral therapy  cart  cont...
# 516  ML_other_1\PMC7301029  this article is protected by copyright  all ri...
# 517  ML_other_1\PMC6919222  unaids and other partners provide support to c...
# 518  ML_covid_1\PMC7273005  osteoporosis is a chronic condition that refle...
# 519  ML_other_1\PMC7083841  to investigate the genetic diversity  spatiote...
# 520  ML_other_1\PMC7214612  during chronic human immunodeficiency virus ty...
# 521  ML_other_1\PMC7093690  transitioning from pediatric to adult care is ...
# 522  ML_other_1\PMC7326772  glutamate  glu  is the most abundant excitator...
# 523  ML_covid_1\PMC7405836  in recent decades  several new diseases have e...
# 524  ML_other_1\PMC7122807  in a context of high rates of hiv prevalence  ...
# 525  ML_covid_1\PMC7326510  as global health systems and communities prepa...
# 526  ML_other_1\PMC7299335  the type one interferon induced restriction fa...
# 527  ML_covid_1\PMC7411421  today clinicians may diagnose hundreds of peop...
# 528  ML_covid_1\PMC7470742                               there is no abstract
# 529  ML_covid_1\PMC7195982  it seems that coronaviruses take an important ...
# 530  ML_other_1\PMC7228895  a 41 year old male with a history of well cont...
# 531  ML_covid_1\PMC7381857  the recent outbreak of the severe acute respir...
# 532  ML_covid_1\PMC7273101  in this opinion piece  we argue the current pa...
# 533  ML_covid_1\PMC7351540  the effect of coronavirus disease 2019  covid ...
# 534  ML_other_1\PMC7239691  currently  most hiv tests are performed with b...
# 535  ML_other_1\PMC7232209  hiv reactivation from latency is induced by cy...
# 536  ML_covid_1\PMC7300871  this article is protected by copyright  all ri...
# 537  ML_other_1\PMC7355883  the effective use of fusion inhibitor peptides...
# 538  ML_covid_1\PMC7472945  while covid 19 pandemic continues to affect ou...
# 539  ML_other_1\PMC7232083  chronic meningococcemia is a rare manifestatio...
#
#      Category
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10      False
# 11      False
# 12       True
# 13      False
# 14      False
# 15       True
# 16       True
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27       True
# 28       True
# 29      False
# ..        ...
# 510     False
# 511     False
# 512     False
# 513      True
# 514     False
# 515     False
# 516     False
# 517     False
# 518      True
# 519     False
# 520     False
# 521     False
# 522     False
# 523      True
# 524     False
# 525      True
# 526     False
# 527      True
# 528      True
# 529      True
# 530     False
# 531      True
# 532      True
# 533      True
# 534     False
# 535     False
# 536      True
# 537     False
# 538      True
# 539     False
#
# [540 rows x 3 columns]

# %%
train_data.head() #visualizing the data table
# Out:
#    Unnamed: 0              ArticleId  \
# 0         382  ML_other_1\PMC7220979
# 1         340  ML_other_1\PMC7137310
# 2         539  ML_other_1\PMC7376523
# 3          95  ML_covid_1\PMC7360122
# 4         523  ML_other_1\PMC7360605
#
#                                                 Text  Category
# 0  alcohol misuse has been associated with negati...     False
# 1  significant advances in the treatment of hiv i...     False
# 2  people living with hiv  plwh  and substance us...     False
# 3  epidemiological data report that several count...      True
# 4  zhuang et al  investigate how low oxygen level...     False

# %%
train_data['category_id'] = train_data['Category'].factorize()[0] # factorizing the output into zero and one

# %%
train_data.groupby('Category').category_id.count().plot.bar(ylim=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # term frequency & inverse document frequency (finding important words within text)
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=2, norm='l2', encoding='latin-1', ngram_range=(1, 3), stop_words='english')
features = tfidf.fit_transform(train_data.Text).toarray()
labels = train_data.category_id

# %%
category_to_id = {'true':0, 'false':1}
id_to_category = {0: 'true', 1: 'fasle'}

# %%
# Use chi-square analysis to find corelation between features (importantce of words) and labels(news category) 
from sklearn.feature_selection import chi2
import numpy as np

N = 3  # We are going to look for top 3 categories

#For each category, find words that are highly corelated to it
for Category, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)                   # Do chi2 analyses of all items in this category
  indices = np.argsort(features_chi2[0])                                  # Sorts the indices of features_chi2[0] - the chi-squared stats of each feature
  feature_names = np.array(tfidf.get_feature_names())[indices]            # Converts indices to feature names ( in increasing order of chi-squared stat values)
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]         # List of single word features ( in increasing order of chi-squared stat values)
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]          # List for two-word features ( in increasing order of chi-squared stat values)
  print("# '{}':".format(Category))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:]))) # Print 3 unigrams with highest Chi squared stat
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:]))) # Print 3 bigrams with highest Chi squared stat
# Out:
# # 'false':
#   . Most correlated unigrams:
#        . 19
#        . covid
#        . hiv
#   . Most correlated bigrams:
#        . hiv infection
#        . sars cov
#        . covid 19
# # 'true':
#   . Most correlated unigrams:
#        . 19
#        . covid
#        . hiv
#   . Most correlated bigrams:
#        . hiv infection
#        . sars cov
#        . covid 19

# %%
##dimension reduction 
from sklearn.manifold import TSNE #low dimensionality plot

# Sampling a subset of our dataset because t-SNE is computationally expensive
SAMPLE_SIZE = int(len(features) * 1)
np.random.seed(0)
indices = np.random.choice(range(len(features)), size=SAMPLE_SIZE, replace=False)          # Randomly select 30 % of samples
projected_features = TSNE(n_components=2, random_state=0).fit_transform(features[indices]) # Array of all projected features of 30% of Randomly chosen samples

# %%
import matplotlib.pyplot as plt

colors = ['pink', 'green']

# Find points belonging to each category and plot them
for category, category_id in sorted(category_to_id.items()):
    points = projected_features[(labels[indices] == category_id).values]
    plt.scatter(points[:, 0], points[:, 1], s=10, c=colors[category_id], label=category)
plt.title("tf-idf feature vector for each article, projected on 2 dimensions.",
          fontdict=dict(fontsize=5))
plt.legend()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import cross_val_score


models = [
    
    RandomForestClassifier(n_estimators=500, max_depth=4, random_state=0),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    KNeighborsClassifier(n_neighbors=3)
]

# %%
CV = 5  # Cross Validate with 5 different folds of 20% data ( 80-20 split with 5 folds )

#Create a data frame that will store the results for all 5 trials of the 3 different models
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = [] # Initially all entries are empty

#For each Algorithm 
for model in models:
  model_name = model.__class__.__name__
  # create 5 models with different 20% test sets, and store their accuracies
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  # Append all 5 accuracies into the entries list ( after all 3 models are run, there will be 3x5 = 15 entries)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))

# %%
# Store the entries into the results dataframe and name its columns    
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
import seaborn as sns

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=5, jitter=True, edgecolor="gray", linewidth=2)

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# KNeighborsClassifier      0.898148
# LogisticRegression        0.937037
# MultinomialNB             0.942593
# RandomForestClassifier    0.911111
# Name: accuracy, dtype: float64

# %%
cv_df
# Out:
#                 model_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.916667
# 1   RandomForestClassifier         1  0.888889
# 2   RandomForestClassifier         2  0.953704
# 3   RandomForestClassifier         3  0.907407
# 4   RandomForestClassifier         4  0.888889
# 5            MultinomialNB         0  0.962963
# 6            MultinomialNB         1  0.935185
# 7            MultinomialNB         2  0.972222
# 8            MultinomialNB         3  0.925926
# 9            MultinomialNB         4  0.916667
# 10      LogisticRegression         0  0.944444
# 11      LogisticRegression         1  0.916667
# 12      LogisticRegression         2  0.981481
# 13      LogisticRegression         3  0.925926
# 14      LogisticRegression         4  0.916667
# 15    KNeighborsClassifier         0  0.935185
# 16    KNeighborsClassifier         1  0.851852
# 17    KNeighborsClassifier         2  0.935185
# 18    KNeighborsClassifier         3  0.870370
# 19    KNeighborsClassifier         4  0.898148

# %%
from sklearn.model_selection import train_test_split

#model = RandomForestClassifier()
model = MultinomialNB()

#Split Data 
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, train_data.index, test_size=0.33, random_state=0)

#Train Algorithm
model.fit(X_train, y_train)

# Make Predictions
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)

# %%
category_id_df = train_data[['Category', 'category_id']].drop_duplicates().sort_values('category_id')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Category.values, yticklabels=category_id_df.Category.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
#run chi squared
# Out:
# Text(0.5, 15.0, 'Predicted')

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
   for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 2:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(train_data.loc[indices_test[(y_test == actual) & (y_pred == predicted)]]['Text'])
      print('')
# Out:
# 'fasle' predicted as 'true' : 3 examples.
# 478    this article is protected by copyright  all ri...
# 497    this article is protected by copyright  all ri...
# 171    this article is protected by copyright  all ri...
# Name: Text, dtype: object
# 'true' predicted as 'fasle' : 10 examples.
# 102    the impact of the covid 19 pandemic is far rea...
# 103                               the proposed impact of
# 175    this cross sectional study investigates whethe...
# 108                 hepatotoxicity is historically the 3
# 78     little is known about the clinical outcomes of...
# 410    alterations in the gut microbiome during hiv i...
# 306    c type lectin receptors  clrs  are carbohydrat...
# 354    biochemistry  structural biology  protein stru...
# 112       histoplasmosis is an endemic mycosis caused by
# 539    chronic meningococcemia is a rare manifestatio...
# Name: Text, dtype: object

# %%
model2 = RandomForestClassifier()
model2.fit(features, labels)
# Out:
# RandomForestClassifier()

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
   for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 2:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(train_data.loc[indices_test[(y_test == actual) & (y_pred == predicted)]]['Text'])
      print('')
# Out:
# 'fasle' predicted as 'true' : 3 examples.
# 478    this article is protected by copyright  all ri...
# 497    this article is protected by copyright  all ri...
# 171    this article is protected by copyright  all ri...
# Name: Text, dtype: object
# 'true' predicted as 'fasle' : 10 examples.
# 102    the impact of the covid 19 pandemic is far rea...
# 103                               the proposed impact of
# 175    this cross sectional study investigates whethe...
# 108                 hepatotoxicity is historically the 3
# 78     little is known about the clinical outcomes of...
# 410    alterations in the gut microbiome during hiv i...
# 306    c type lectin receptors  clrs  are carbohydrat...
# 354    biochemistry  structural biology  protein stru...
# 112       histoplasmosis is an endemic mycosis caused by
# 539    chronic meningococcemia is a rare manifestatio...
# Name: Text, dtype: object
